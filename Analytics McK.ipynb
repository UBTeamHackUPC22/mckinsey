# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
df_geo = pd.read_csv('Data - Hack UPC/geo_params.csv')
df_sales = pd.read_csv('Data - Hack UPC/sales.csv')
df_sku = pd.read_csv('Data - Hack UPC/sku.csv')
test = pd.read_csv('Data - Hack UPC/test.csv')

# %% [markdown]
# ## Geo file

# %% [markdown]
# The geo_params variables are the following:
#    - **geoCluster**: Number of a concrete zone in a city
#    - **cityId**: City in which the geoCluster came from.

# %% [markdown]
# ## Sku file

# %% [markdown]
# The sku variables are the following:
#    - **SKU**: Unique code of SKU (Stock Keeping Unit), which identifies the smallest sales unit.
#    - **Category**: The name of the set in which the Unit belongs.
#    - **Type**: ?
#    - **brandId**: Id of the branding in which this product belongs
#    - **largerUnitQuantity**: ?
#    - **Units**: Unkown, suppose number of units per SKU but itself express the smallest sales unit.
#    - **trademark**: trademark number is the number that is assigned to a pending or registered trademark.
#    - **countryOfOrigin**: Origin in which the product comes
#    - **Group**: Set in which categories belong to

# %% [markdown]
# ## Data change

# %%
df_sku.Category.fillna(df_sku.Group, inplace=True)
df_sku.brandId.fillna(0, inplace=True) # Meaning other
df_sku.trademark.fillna(0, inplace=True) # Meaning other
df_sku.countryOfOrigin.fillna(0, inplace=True) # Meaning other

df_sku["Category"] = df_sku["Category"].astype("category")
df_sku["Group"] = df_sku["Group"].astype("category")
df_sku["brandId"] = df_sku["brandId"].astype("Int64")
df_sku["trademark"] = df_sku["trademark"].astype("Int64")
df_sku["countryOfOrigin"] = df_sku["countryOfOrigin"].astype("Int64")
df_sku["lagerUnitQuantity"] = df_sku["lagerUnitQuantity"].astype("Float64")

df_sku.drop(['Units', 'Type'], axis=1, inplace=True)

df_sku.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SKU                60 non-null     int64
#  1   Category           60 non-null     category
#  2   brandId            60 non-null     Int64
#  3   lagerUnitQuantity  60 non-null     Float64
#  4   trademark          60 non-null     Int64
#  5   countryOfOrigin    60 non-null     Int64
#  6   Group              60 non-null     category
# dtypes: Float64(1), Int64(3), category(2), int64(1)
# memory usage: 4.4 KB

# %% [markdown]
# ## Sales file

# %% [markdown]
# The sku variables are the following:
#    - **ID**: id of the sale
#    - **geoCluster**: Key of geo csv
#    - **SKU**: Key of SKU csv
#    - **date**: date in which the sale was done
#    - **price**: price of the sale
#    - **sales**: number of sales.

# %% [markdown]
# ## Merge Dataframes

# %% [markdown]
# In order to look better the data, we will need to merge the 3 dataframes into a single one.

# %%
def merging_df(df_geo, df_sales, df_sku):
    df = pd.merge(df_geo, df_sales, on=["geoCluster"])
    return pd.merge(df_sku, df, on=["SKU"])

# %%
df = merging_df(df_geo, df_sales, df_sku)
df
# Out:
#             SKU     Category  brandId  lagerUnitQuantity  trademark  \
# 0            24  Pomegranate        0                1.0          0
# 1            24  Pomegranate        0                1.0          0
# 2            24  Pomegranate        0                1.0          0
# 3            24  Pomegranate        0                1.0          0
# 4            24  Pomegranate        0                1.0          0
# ...         ...          ...      ...                ...        ...
# 4605980  838137      Avocado        0                1.0       9666
# 4605981  838137      Avocado        0                1.0       9666
# 4605982  838137      Avocado        0                1.0       9666
# 4605983  838137      Avocado        0                1.0       9666
# 4605984  838137      Avocado        0                1.0       9666
#
#          countryOfOrigin            Group  geoCluster  cityId          ID  \
# 0                      0  Tropical fruits         323       1  RR27958444
# 1                      0  Tropical fruits         323       1  RR27958445
# 2                      0  Tropical fruits         323       1  RR27958446
# 3                      0  Tropical fruits         323       1  RR27958447
# 4                      0  Tropical fruits         323       1  RR27958448
# ...                  ...              ...         ...     ...         ...
# 4605980                0  Tropical fruits        3230       0  RR31319305
# 4605981                0  Tropical fruits        3230       0  RR31319306
# 4605982                0  Tropical fruits        3230       0  RR31319307
# 4605983                0  Tropical fruits        3230       0  RR31319308
# 4605984                0  Tropical fruits        3230       0  RR31319309
#
#                date  price  sales
# 0        2021-03-03  79.49    0.4
# 1        2021-03-04    NaN    NaN
# 2        2021-03-05    NaN    NaN
# 3        2021-03-06    NaN    NaN
# 4        2021-03-07    NaN    NaN
# ...             ...    ...    ...
# 4605980  2021-07-01  39.79    7.0
# 4605981  2021-07-02  39.79    6.0
# 4605982  2021-07-03  39.79   21.0
# 4605983  2021-07-04  39.39   20.0
# 4605984  2021-07-05  38.69    8.0
#
# [4605985 rows x 13 columns]

# %% [markdown]
# ## Refactor

# %%
df.date = pd.to_datetime(df.date) #Change data type to datetime
df = df.dropna(subset=['sales']).reset_index()
df.drop(['index', 'ID'], axis=1, inplace=True)

# %%
df
# Out:
#            SKU     Category  brandId  lagerUnitQuantity  trademark  \
# 0           24  Pomegranate        0                1.0          0
# 1           24  Pomegranate        0                1.0          0
# 2           24  Pomegranate        0                1.0          0
# 3           24  Pomegranate        0                1.0          0
# 4           24  Pomegranate        0                1.0          0
# ...        ...          ...      ...                ...        ...
# 778361  838137      Avocado        0                1.0       9666
# 778362  838137      Avocado        0                1.0       9666
# 778363  838137      Avocado        0                1.0       9666
# 778364  838137      Avocado        0                1.0       9666
# 778365  838137      Avocado        0                1.0       9666
#
#         countryOfOrigin            Group  geoCluster  cityId       date  \
# 0                     0  Tropical fruits         323       1 2021-03-03
# 1                     0  Tropical fruits        1934       0 2020-11-05
# 2                     0  Tropical fruits        1934       0 2020-11-26
# 3                     0  Tropical fruits        1934       0 2020-11-28
# 4                     0  Tropical fruits        1934       0 2020-12-09
# ...                 ...              ...         ...     ...        ...
# 778361                0  Tropical fruits        3230       0 2021-07-01
# 778362                0  Tropical fruits        3230       0 2021-07-02
# 778363                0  Tropical fruits        3230       0 2021-07-03
# 778364                0  Tropical fruits        3230       0 2021-07-04
# 778365                0  Tropical fruits        3230       0 2021-07-05
#
#         price  sales
# 0       79.49    0.4
# 1       46.89    1.4
# 2       54.09    2.5
# 3       54.09    1.4
# 4       62.39    3.0
# ...       ...    ...
# 778361  39.79    7.0
# 778362  39.79    6.0
# 778363  39.79   21.0
# 778364  39.39   20.0
# 778365  38.69    8.0
#
# [778366 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 778366 entries, 0 to 778365
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   SKU                778366 non-null  int64
#  1   Category           778366 non-null  category
#  2   brandId            778366 non-null  Int64
#  3   lagerUnitQuantity  778366 non-null  Float64
#  4   trademark          778366 non-null  Int64
#  5   countryOfOrigin    778366 non-null  Int64
#  6   Group              778366 non-null  category
#  7   geoCluster         778366 non-null  int64
#  8   cityId             778366 non-null  int64
#  9   date               778366 non-null  datetime64[ns]
#  10  price              778366 non-null  float64
#  11  sales              778366 non-null  float64
# dtypes: Float64(1), Int64(3), category(2), datetime64[ns](1), float64(2), int64(3)
# memory usage: 63.8 MB

# %% [markdown]
# ## Train

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Category'] = le.fit_transform(df['Category'])
mapping_categories = dict(zip(le.classes_, range(len(le.classes_))))

df['Group'] = le.fit_transform(df['Group'])
mapping_group = dict(zip(le.classes_, range(len(le.classes_))))

mapping_group
# Out:
# {'Bakery': 0,
#  'Cheese': 1,
#  'Mineral water': 2,
#  'Tropical fruits': 3,
#  'Yogurts': 4}

# %%
import datetime as dt

df.date = pd.to_datetime(df.date) 
df.date = df.date .map(dt.datetime.toordinal)
df['date'] = df['date'].astype(np.int64)

# %%
df
# Out:
#            SKU  Category  brandId  lagerUnitQuantity  trademark  \
# 0           24        24        0                1.0          0
# 1           24        24        0                1.0          0
# 2           24        24        0                1.0          0
# 3           24        24        0                1.0          0
# 4           24        24        0                1.0          0
# ...        ...       ...      ...                ...        ...
# 778361  838137         0        0                1.0       9666
# 778362  838137         0        0                1.0       9666
# 778363  838137         0        0                1.0       9666
# 778364  838137         0        0                1.0       9666
# 778365  838137         0        0                1.0       9666
#
#         countryOfOrigin  Group  geoCluster  cityId    date  price  sales
# 0                     0      3         323       1  737852  79.49    0.4
# 1                     0      3        1934       0  737734  46.89    1.4
# 2                     0      3        1934       0  737755  54.09    2.5
# 3                     0      3        1934       0  737757  54.09    1.4
# 4                     0      3        1934       0  737768  62.39    3.0
# ...                 ...    ...         ...     ...     ...    ...    ...
# 778361                0      3        3230       0  737972  39.79    7.0
# 778362                0      3        3230       0  737973  39.79    6.0
# 778363                0      3        3230       0  737974  39.79   21.0
# 778364                0      3        3230       0  737975  39.39   20.0
# 778365                0      3        3230       0  737976  38.69    8.0
#
# [778366 rows x 12 columns]

# %%
df['brandId'] = df['brandId'].astype("int64")
df['Group'] = df['Group'].astype("int64")
df['Category'] = df['Category'].astype("int64")
df['SKU'] = df['SKU'].astype("int64")
df['geoCluster'] = df['geoCluster'].astype("int64")
df["cityId"] = df['cityId'].astype("int64")
df["date"] = df["date"].astype("int64")
df["price"] = df["price"].astype("float64")
df['lagerUnitQuantity'] = df['lagerUnitQuantity'].astype('float64')
df['trademark'] = df['trademark'].astype('int64')
df['countryOfOrigin'] = df['countryOfOrigin'].astype('int64')

# %%
copy_df = df.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 778366 entries, 0 to 778365
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   SKU                778366 non-null  int64
#  1   Category           778366 non-null  int64
#  2   brandId            778366 non-null  int64
#  3   lagerUnitQuantity  778366 non-null  float64
#  4   trademark          778366 non-null  int64
#  5   countryOfOrigin    778366 non-null  int64
#  6   Group              778366 non-null  int64
#  7   geoCluster         778366 non-null  int64
#  8   cityId             778366 non-null  int64
#  9   date               778366 non-null  int64
#  10  price              778366 non-null  float64
#  11  sales              778366 non-null  float64
# dtypes: float64(3), int64(9)
# memory usage: 71.3 MB

# %%
testing_df = df.copy()

# %% [markdown]
# ## SW Modelling per Category

# %%
import copy

def get_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(11,)),
        tf.keras.layers.Dense(100, activation='relu'),
        tf.keras.layers.Dense(100, activation='relu'),
        tf.keras.layers.Dense(100, activation='relu'),
        tf.keras.layers.Dense(100, activation='relu'),
        tf.keras.layers.Dense(1)
      ])

    model.compile(optimizer='adam',
                loss=tf.keras.losses.MeanSquaredError(),
                metrics=['RootMeanSquaredError'])
    return model

class ModelslNetworksCategory:
    def __init__(self, model_gen, num_categories):
        self.models = [model_gen() for x in range(num_categories)]
        self.num_categories = num_categories
        self.historials = {}
        
    def fit_group(self, X_train, y_train, X_test, y_test, num_category):
        self.historials[num_category] = self.models[num_category].fit(X_train, 
                                                                      y_train, 
                                                                      epochs=30, 
                                                                      validation_data=(X_test, Y_test))
        
    def predict(self, X, num_category):
        return self.models[num_category].predict(X)

# %%
get_model().summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_14 (Flatten)        (None, 11)                0
#
#  dense_69 (Dense)            (None, 100)               1200
#
#  dense_70 (Dense)            (None, 100)               10100
#
#  dense_71 (Dense)            (None, 100)               10100
#
#  dense_72 (Dense)            (None, 100)               10100
#
#  dense_73 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 31,601
# Trainable params: 31,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
macroModel = ModelslNetworksCategory(get_model, len(testing_df.Group.unique()))

# %%
testing_df = df.copy()

# %%
mapping_group
# Out:
# {'Bakery': 0,
#  'Cheese': 1,
#  'Mineral water': 2,
#  'Tropical fruits': 3,
#  'Yogurts': 4}

# %%
testing_df
# Out:
#            SKU  Category  brandId  lagerUnitQuantity  trademark  \
# 0           24        24        0                1.0          0
# 1           24        24        0                1.0          0
# 2           24        24        0                1.0          0
# 3           24        24        0                1.0          0
# 4           24        24        0                1.0          0
# ...        ...       ...      ...                ...        ...
# 778361  838137         0        0                1.0       9666
# 778362  838137         0        0                1.0       9666
# 778363  838137         0        0                1.0       9666
# 778364  838137         0        0                1.0       9666
# 778365  838137         0        0                1.0       9666
#
#         countryOfOrigin  Group  geoCluster  cityId    date  price  sales
# 0                     0      3         323       1  737852  79.49    0.4
# 1                     0      3        1934       0  737734  46.89    1.4
# 2                     0      3        1934       0  737755  54.09    2.5
# 3                     0      3        1934       0  737757  54.09    1.4
# 4                     0      3        1934       0  737768  62.39    3.0
# ...                 ...    ...         ...     ...     ...    ...    ...
# 778361                0      3        3230       0  737972  39.79    7.0
# 778362                0      3        3230       0  737973  39.79    6.0
# 778363                0      3        3230       0  737974  39.79   21.0
# 778364                0      3        3230       0  737975  39.39   20.0
# 778365                0      3        3230       0  737976  38.69    8.0
#
# [778366 rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split

def get_data_model(a, test_size):
    target = a.pop('sales')
    X_train, X_test, Y_train, Y_test = train_test_split(group_data, target, test_size=0.2)
    return X_train, X_test, Y_train, Y_test

# %%
for group in testing_df.Group.unique():
    group_data = testing_df[testing_df.Group == group].copy()
    X_train, X_test, Y_train, Y_test = get_data_model(group_data, 0.2)
    
    numeric_features_train = tf.convert_to_tensor(X_train)
    numeric_features_test = tf.convert_to_tensor(X_test)

    normalizer = tf.keras.layers.Normalization(axis=-1)
    normalizer.adapt(numeric_features_train)
    normalizer.adapt(numeric_features_test)
    
    print('-------------------------')
    print('Training number: ',group)
    macroModel.fit_group(numeric_features_train, Y_train, numeric_features_test, Y_test, group)
    print('-------------------------')
# Out:
# -------------------------
# Training number:  3
# Epoch 1/30
# 6203/6203 [==============================] - 10s 2ms/step - loss: 556655.5625 - root_mean_squared_error: 746.0935 - val_loss: 3824.5085 - val_root_mean_squared_error: 61.8426
# Epoch 2/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 10060.5449 - root_mean_squared_error: 100.3023 - val_loss: 107.5461 - val_root_mean_squared_error: 10.3704
# Epoch 3/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 1488.4242 - root_mean_squared_error: 38.5801 - val_loss: 34.5983 - val_root_mean_squared_error: 5.8820
# Epoch 4/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 1373.0146 - root_mean_squared_error: 37.0542 - val_loss: 26.9291 - val_root_mean_squared_error: 5.1893
# Epoch 5/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 60.4695 - root_mean_squared_error: 7.7762 - val_loss: 64.7864 - val_root_mean_squared_error: 8.0490
# Epoch 6/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 216.4078 - root_mean_squared_error: 14.7108 - val_loss: 22.5338 - val_root_mean_squared_error: 4.7470
# Epoch 7/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 146.4960 - root_mean_squared_error: 12.1036 - val_loss: 22.7672 - val_root_mean_squared_error: 4.7715
# Epoch 8/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 25.7303 - root_mean_squared_error: 5.0725 - val_loss: 25.3938 - val_root_mean_squared_error: 5.0392
# Epoch 9/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 23.9979 - root_mean_squared_error: 4.8988 - val_loss: 23.6710 - val_root_mean_squared_error: 4.8653
# Epoch 10/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 23.9415 - root_mean_squared_error: 4.8930 - val_loss: 23.6647 - val_root_mean_squared_error: 4.8646
# Epoch 11/30
# 6203/6203 [==============================] - 9s 2ms/step - loss: 23.9459 - root_mean_squared_error: 4.8935 - val_loss: 23.7065 - val_root_mean_squared_error: 4.8689
# Epoch 12/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 23.9463 - root_mean_squared_error: 4.8935 - val_loss: 23.6816 - val_root_mean_squared_error: 4.8664
# Epoch 13/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 23.9477 - root_mean_squared_error: 4.8936 - val_loss: 23.6794 - val_root_mean_squared_error: 4.8661
# Epoch 14/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 23.9454 - root_mean_squared_error: 4.8934 - val_loss: 23.6639 - val_root_mean_squared_error: 4.8646
# Epoch 15/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 23.9448 - root_mean_squared_error: 4.8933 - val_loss: 23.6704 - val_root_mean_squared_error: 4.8652
# Epoch 16/30
# 6203/6203 [==============================] - 9s 2ms/step - loss: 23.9426 - root_mean_squared_error: 4.8931 - val_loss: 23.6641 - val_root_mean_squared_error: 4.8646
# Epoch 17/30
# 6203/6203 [==============================] - 9s 2ms/step - loss: 23.9434 - root_mean_squared_error: 4.8932 - val_loss: 23.6779 - val_root_mean_squared_error: 4.8660
# Epoch 18/30
# 6203/6203 [==============================] - 9s 2ms/step - loss: 23.9446 - root_mean_squared_error: 4.8933 - val_loss: 23.6955 - val_root_mean_squared_error: 4.8678
# Epoch 19/30
# 6203/6203 [==============================] - 9s 2ms/step - loss: 23.9438 - root_mean_squared_error: 4.8932 - val_loss: 23.6697 - val_root_mean_squared_error: 4.8651
# Epoch 20/30
# 6203/6203 [==============================] - 9s 2ms/step - loss: 23.9456 - root_mean_squared_error: 4.8934 - val_loss: 23.6694 - val_root_mean_squared_error: 4.8651
# Epoch 21/30
# 6203/6203 [==============================] - 10s 2ms/step - loss: 23.9430 - root_mean_squared_error: 4.8932 - val_loss: 23.6871 - val_root_mean_squared_error: 4.8669
# Epoch 22/30
# 6203/6203 [==============================] - 9s 2ms/step - loss: 23.9451 - root_mean_squared_error: 4.8934 - val_loss: 23.6644 - val_root_mean_squared_error: 4.8646
# Epoch 23/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 23.9445 - root_mean_squared_error: 4.8933 - val_loss: 23.6838 - val_root_mean_squared_error: 4.8666
# Epoch 24/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 23.9440 - root_mean_squared_error: 4.8933 - val_loss: 23.6724 - val_root_mean_squared_error: 4.8654
# Epoch 25/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 23.9439 - root_mean_squared_error: 4.8932 - val_loss: 23.6725 - val_root_mean_squared_error: 4.8654
# Epoch 26/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 23.9433 - root_mean_squared_error: 4.8932 - val_loss: 23.6639 - val_root_mean_squared_error: 4.8646
# Epoch 27/30
# 6203/6203 [==============================] - 9s 2ms/step - loss: 23.9424 - root_mean_squared_error: 4.8931 - val_loss: 23.6655 - val_root_mean_squared_error: 4.8647
# Epoch 28/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 23.9425 - root_mean_squared_error: 4.8931 - val_loss: 23.6690 - val_root_mean_squared_error: 4.8651
# Epoch 29/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 23.9436 - root_mean_squared_error: 4.8932 - val_loss: 23.6704 - val_root_mean_squared_error: 4.8652
# Epoch 30/30
# 6203/6203 [==============================] - 9s 1ms/step - loss: 23.9425 - root_mean_squared_error: 4.8931 - val_loss: 23.6797 - val_root_mean_squared_error: 4.8662
# -------------------------
# -------------------------
# Training number:  2
# Epoch 1/30
# 3724/3724 [==============================] - 6s 1ms/step - loss: 15969694.0000 - root_mean_squared_error: 3996.2100 - val_loss: 388.8887 - val_root_mean_squared_error: 19.7203
# Epoch 2/30
# 3724/3724 [==============================] - 5s 1ms/step - loss: 35649.5195 - root_mean_squared_error: 188.8108 - val_loss: 590.2985 - val_root_mean_squared_error: 24.2961
# Epoch 3/30
# 3724/3724 [==============================] - 5s 1ms/step - loss: 14648.7646 - root_mean_squared_error: 121.0321 - val_loss: 342.9987 - val_root_mean_squared_error: 18.5202
# Epoch 4/30
# 3724/3724 [==============================] - 5s 1ms/step - loss: 30389.8457 - root_mean_squared_error: 174.3268 - val_loss: 893.1444 - val_root_mean_squared_error: 29.8855
# Epoch 5/30
# 3724/3724 [==============================] - 5s 1ms/step - loss: 15092.6602 - root_mean_squared_error: 122.8522 - val_loss: 52.4588 - val_root_mean_squared_error: 7.2428
# Epoch 6/30
# 3724/3724 [==============================] - 5s 1ms/step - loss: 72.6708 - root_mean_squared_error: 8.5247 - val_loss: 189.4504 - val_root_mean_squared_error: 13.7641
# Epoch 7/30
# 3724/3724 [==============================] - 6s 2ms/step - loss: 178.3814 - root_mean_squared_error: 13.3560 - val_loss: 173.3982 - val_root_mean_squared_error: 13.1681
# Epoch 8/30
# 3724/3724 [==============================] - 6s 2ms/step - loss: 1381.9854 - root_mean_squared_error: 37.1751 - val_loss: 57.3394 - val_root_mean_squared_error: 7.5723
# Epoch 9/30
# 3724/3724 [==============================] - 6s 1ms/step - loss: 98.1395 - root_mean_squared_error: 9.9065 - val_loss: 57.7588 - val_root_mean_squared_error: 7.5999
# Epoch 10/30
# 3724/3724 [==============================] - 6s 1ms/step - loss: 64.5053 - root_mean_squared_error: 8.0315 - val_loss: 80.4283 - val_root_mean_squared_error: 8.9682
# Epoch 11/30
# 3724/3724 [==============================] - 6s 2ms/step - loss: 2921.6113 - root_mean_squared_error: 54.0519 - val_loss: 51.5333 - val_root_mean_squared_error: 7.1787
# Epoch 12/30
# 3724/3724 [==============================] - 6s 2ms/step - loss: 55.6127 - root_mean_squared_error: 7.4574 - val_loss: 47.2014 - val_root_mean_squared_error: 6.8703
# Epoch 13/30
# 3724/3724 [==============================] - 6s 1ms/step - loss: 49.9093 - root_mean_squared_error: 7.0647 - val_loss: 47.3737 - val_root_mean_squared_error: 6.8829
# Epoch 14/30
# 3724/3724 [==============================] - 6s 2ms/step - loss: 49.7998 - root_mean_squared_error: 7.0569 - val_loss: 47.3327 - val_root_mean_squared_error: 6.8799
# Epoch 15/30
# 3724/3724 [==============================] - 6s 2ms/step - loss: 49.8046 - root_mean_squared_error: 7.0572 - val_loss: 47.3343 - val_root_mean_squared_error: 6.8800
# Epoch 16/30
# 3724/3724 [==============================] - 5s 1ms/step - loss: 49.8088 - root_mean_squared_error: 7.0575 - val_loss: 47.3417 - val_root_mean_squared_error: 6.8805
# Epoch 17/30
# 3724/3724 [==============================] - 5s 1ms/step - loss: 49.8125 - root_mean_squared_error: 7.0578 - val_loss: 47.3319 - val_root_mean_squared_error: 6.8798
# Epoch 18/30
# 3724/3724 [==============================] - 5s 1ms/step - loss: 49.8174 - root_mean_squared_error: 7.0581 - val_loss: 47.3389 - val_root_mean_squared_error: 6.8803
# Epoch 19/30
# 3724/3724 [==============================] - 5s 1ms/step - loss: 49.8159 - root_mean_squared_error: 7.0580 - val_loss: 47.3364 - val_root_mean_squared_error: 6.8801
# Epoch 20/30
# 3724/3724 [==============================] - 5s 1ms/step - loss: 49.8100 - root_mean_squared_error: 7.0576 - val_loss: 47.3649 - val_root_mean_squared_error: 6.8822
# Epoch 21/30
# 3724/3724 [==============================] - 6s 2ms/step - loss: 49.8125 - root_mean_squared_error: 7.0578 - val_loss: 47.5023 - val_root_mean_squared_error: 6.8922
# Epoch 22/30
# 3724/3724 [==============================] - 6s 1ms/step - loss: 49.8144 - root_mean_squared_error: 7.0579 - val_loss: 47.3319 - val_root_mean_squared_error: 6.8798
# Epoch 23/30
# 3724/3724 [==============================] - 5s 1ms/step - loss: 49.8077 - root_mean_squared_error: 7.0575 - val_loss: 47.3730 - val_root_mean_squared_error: 6.8828
# Epoch 24/30
# 3724/3724 [==============================] - 5s 1ms/step - loss: 49.8104 - root_mean_squared_error: 7.0576 - val_loss: 47.3549 - val_root_mean_squared_error: 6.8815
# Epoch 25/30
# 3724/3724 [==============================] - 5s 1ms/step - loss: 49.8062 - root_mean_squared_error: 7.0574 - val_loss: 47.3497 - val_root_mean_squared_error: 6.8811
# Epoch 26/30
# 3724/3724 [==============================] - 5s 1ms/step - loss: 49.8015 - root_mean_squared_error: 7.0570 - val_loss: 47.3338 - val_root_mean_squared_error: 6.8800
# Epoch 27/30
# 3724/3724 [==============================] - 5s 1ms/step - loss: 49.8048 - root_mean_squared_error: 7.0573 - val_loss: 47.3631 - val_root_mean_squared_error: 6.8821
# Epoch 28/30
# 3724/3724 [==============================] - 5s 1ms/step - loss: 49.8065 - root_mean_squared_error: 7.0574 - val_loss: 47.4391 - val_root_mean_squared_error: 6.8876
# Epoch 29/30
# 3724/3724 [==============================] - 6s 1ms/step - loss: 49.8034 - root_mean_squared_error: 7.0571 - val_loss: 47.3330 - val_root_mean_squared_error: 6.8799
# Epoch 30/30
# 3724/3724 [==============================] - 6s 1ms/step - loss: 49.8072 - root_mean_squared_error: 7.0574 - val_loss: 47.3358 - val_root_mean_squared_error: 6.8801
# -------------------------
# -------------------------
# Training number:  1
# Epoch 1/30
# 1798/1798 [==============================] - 3s 2ms/step - loss: 1908593.6250 - root_mean_squared_error: 1381.5186 - val_loss: 42.6059 - val_root_mean_squared_error: 6.5273
# Epoch 2/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 190267.2812 - root_mean_squared_error: 436.1964 - val_loss: 181236.7656 - val_root_mean_squared_error: 425.7191
# Epoch 3/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 13800.0977 - root_mean_squared_error: 117.4738 - val_loss: 34.5979 - val_root_mean_squared_error: 5.8820
# Epoch 4/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 27778.3633 - root_mean_squared_error: 166.6684 - val_loss: 22.7783 - val_root_mean_squared_error: 4.7727
# Epoch 5/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 2868.4023 - root_mean_squared_error: 53.5575 - val_loss: 10509.3018 - val_root_mean_squared_error: 102.5149
# Epoch 6/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 47729.7656 - root_mean_squared_error: 218.4714 - val_loss: 648.0749 - val_root_mean_squared_error: 25.4573
# Epoch 7/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 1977.2538 - root_mean_squared_error: 44.4663 - val_loss: 133.6597 - val_root_mean_squared_error: 11.5611
# Epoch 8/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 1859.8474 - root_mean_squared_error: 43.1259 - val_loss: 9.2446 - val_root_mean_squared_error: 3.0405
# Epoch 9/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 225.0245 - root_mean_squared_error: 15.0008 - val_loss: 50.0433 - val_root_mean_squared_error: 7.0741
# Epoch 10/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 19074.9707 - root_mean_squared_error: 138.1122 - val_loss: 45.0102 - val_root_mean_squared_error: 6.7090
# Epoch 11/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 5.5006 - root_mean_squared_error: 2.3453 - val_loss: 2.1095 - val_root_mean_squared_error: 1.4524
# Epoch 12/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 112.5274 - root_mean_squared_error: 10.6079 - val_loss: 2474.5596 - val_root_mean_squared_error: 49.7449
# Epoch 13/30
# 1798/1798 [==============================] - 3s 2ms/step - loss: 99.0641 - root_mean_squared_error: 9.9531 - val_loss: 1.9749 - val_root_mean_squared_error: 1.4053
# Epoch 14/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 37.9289 - root_mean_squared_error: 6.1586 - val_loss: 1.5177 - val_root_mean_squared_error: 1.2319
# Epoch 15/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 17.8769 - root_mean_squared_error: 4.2281 - val_loss: 1.0989 - val_root_mean_squared_error: 1.0483
# Epoch 16/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 6.8442 - root_mean_squared_error: 2.6161 - val_loss: 1.1091 - val_root_mean_squared_error: 1.0531
# Epoch 17/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 1830.8103 - root_mean_squared_error: 42.7880 - val_loss: 1.5754 - val_root_mean_squared_error: 1.2552
# Epoch 18/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 9.1619 - root_mean_squared_error: 3.0269 - val_loss: 33.1690 - val_root_mean_squared_error: 5.7593
# Epoch 19/30
# 1798/1798 [==============================] - 3s 2ms/step - loss: 48.4548 - root_mean_squared_error: 6.9609 - val_loss: 0.5715 - val_root_mean_squared_error: 0.7560
# Epoch 20/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 7.5991 - root_mean_squared_error: 2.7566 - val_loss: 15.8934 - val_root_mean_squared_error: 3.9867
# Epoch 21/30
# 1798/1798 [==============================] - 3s 2ms/step - loss: 4.7211 - root_mean_squared_error: 2.1728 - val_loss: 0.8758 - val_root_mean_squared_error: 0.9358
# Epoch 22/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 1.1849 - root_mean_squared_error: 1.0885 - val_loss: 0.3427 - val_root_mean_squared_error: 0.5854
# Epoch 23/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 641.4818 - root_mean_squared_error: 25.3275 - val_loss: 0.3393 - val_root_mean_squared_error: 0.5825
# Epoch 24/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 0.4086 - root_mean_squared_error: 0.6392 - val_loss: 0.3892 - val_root_mean_squared_error: 0.6239
# Epoch 25/30
# 1798/1798 [==============================] - 3s 2ms/step - loss: 1.2722 - root_mean_squared_error: 1.1279 - val_loss: 1.9203 - val_root_mean_squared_error: 1.3857
# Epoch 26/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 2.2209 - root_mean_squared_error: 1.4903 - val_loss: 1.3952 - val_root_mean_squared_error: 1.1812
# Epoch 27/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 0.8411 - root_mean_squared_error: 0.9171 - val_loss: 0.5949 - val_root_mean_squared_error: 0.7713
# Epoch 28/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 0.4670 - root_mean_squared_error: 0.6834 - val_loss: 0.3552 - val_root_mean_squared_error: 0.5960
# Epoch 29/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 0.3276 - root_mean_squared_error: 0.5724 - val_loss: 0.3343 - val_root_mean_squared_error: 0.5782
# Epoch 30/30
# 1798/1798 [==============================] - 3s 1ms/step - loss: 0.3124 - root_mean_squared_error: 0.5589 - val_loss: 0.3319 - val_root_mean_squared_error: 0.5761
# -------------------------
# -------------------------
# Training number:  4
# Epoch 1/30
# 2309/2309 [==============================] - 4s 1ms/step - loss: 7380155.5000 - root_mean_squared_error: 2716.6440 - val_loss: 44.9632 - val_root_mean_squared_error: 6.7055
# Epoch 2/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 54378.4414 - root_mean_squared_error: 233.1918 - val_loss: 3097.0120 - val_root_mean_squared_error: 55.6508
# Epoch 3/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 43687.5742 - root_mean_squared_error: 209.0157 - val_loss: 698.2083 - val_root_mean_squared_error: 26.4236
# Epoch 4/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 18111.9590 - root_mean_squared_error: 134.5807 - val_loss: 106.0480 - val_root_mean_squared_error: 10.2980
# Epoch 5/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 211804.2188 - root_mean_squared_error: 460.2219 - val_loss: 132936.2344 - val_root_mean_squared_error: 364.6042
# Epoch 6/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 6669.2812 - root_mean_squared_error: 81.6657 - val_loss: 72.1152 - val_root_mean_squared_error: 8.4921
# Epoch 7/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 2234.5713 - root_mean_squared_error: 47.2713 - val_loss: 43.9159 - val_root_mean_squared_error: 6.6269
# Epoch 8/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 1326.1918 - root_mean_squared_error: 36.4169 - val_loss: 31.2865 - val_root_mean_squared_error: 5.5934
# Epoch 9/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 94.5534 - root_mean_squared_error: 9.7239 - val_loss: 1336.9176 - val_root_mean_squared_error: 36.5639
# Epoch 10/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 15719.1826 - root_mean_squared_error: 125.3762 - val_loss: 14.4536 - val_root_mean_squared_error: 3.8018
# Epoch 11/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 82.3732 - root_mean_squared_error: 9.0760 - val_loss: 48.5545 - val_root_mean_squared_error: 6.9681
# Epoch 12/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 45.9708 - root_mean_squared_error: 6.7802 - val_loss: 15.9241 - val_root_mean_squared_error: 3.9905
# Epoch 13/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 14.4016 - root_mean_squared_error: 3.7949 - val_loss: 8.8925 - val_root_mean_squared_error: 2.9820
# Epoch 14/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 18.9668 - root_mean_squared_error: 4.3551 - val_loss: 6.2032 - val_root_mean_squared_error: 2.4906
# Epoch 15/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 6.9691 - root_mean_squared_error: 2.6399 - val_loss: 6.1180 - val_root_mean_squared_error: 2.4735
# Epoch 16/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 7.4088 - root_mean_squared_error: 2.7219 - val_loss: 6.1266 - val_root_mean_squared_error: 2.4752
# Epoch 17/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 6.7123 - root_mean_squared_error: 2.5908 - val_loss: 6.1263 - val_root_mean_squared_error: 2.4751
# Epoch 18/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 6.7132 - root_mean_squared_error: 2.5910 - val_loss: 6.1267 - val_root_mean_squared_error: 2.4752
# Epoch 19/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 6.7134 - root_mean_squared_error: 2.5910 - val_loss: 6.1264 - val_root_mean_squared_error: 2.4752
# Epoch 20/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 6.7124 - root_mean_squared_error: 2.5908 - val_loss: 6.1285 - val_root_mean_squared_error: 2.4756
# Epoch 21/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 6.7144 - root_mean_squared_error: 2.5912 - val_loss: 6.1328 - val_root_mean_squared_error: 2.4765
# Epoch 22/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 6.7158 - root_mean_squared_error: 2.5915 - val_loss: 6.1267 - val_root_mean_squared_error: 2.4752
# Epoch 23/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 6.7163 - root_mean_squared_error: 2.5916 - val_loss: 6.1265 - val_root_mean_squared_error: 2.4752
# Epoch 24/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 6.7168 - root_mean_squared_error: 2.5917 - val_loss: 6.1529 - val_root_mean_squared_error: 2.4805
# Epoch 25/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 6.7172 - root_mean_squared_error: 2.5918 - val_loss: 6.1263 - val_root_mean_squared_error: 2.4751
# Epoch 26/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 6.7160 - root_mean_squared_error: 2.5915 - val_loss: 6.1268 - val_root_mean_squared_error: 2.4752
# Epoch 27/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 6.7177 - root_mean_squared_error: 2.5918 - val_loss: 6.1584 - val_root_mean_squared_error: 2.4816
# Epoch 28/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 6.7193 - root_mean_squared_error: 2.5922 - val_loss: 6.1274 - val_root_mean_squared_error: 2.4754
# Epoch 29/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 6.7196 - root_mean_squared_error: 2.5922 - val_loss: 6.1266 - val_root_mean_squared_error: 2.4752
# Epoch 30/30
# 2309/2309 [==============================] - 3s 1ms/step - loss: 6.7174 - root_mean_squared_error: 2.5918 - val_loss: 6.1279 - val_root_mean_squared_error: 2.4755
# -------------------------
# -------------------------
# Training number:  0
# Epoch 1/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 1030523.1250 - root_mean_squared_error: 1015.1469 - val_loss: 2039.0771 - val_root_mean_squared_error: 45.1561
# Epoch 2/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 102091.0000 - root_mean_squared_error: 319.5168 - val_loss: 66.3107 - val_root_mean_squared_error: 8.1431
# Epoch 3/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 451.7256 - root_mean_squared_error: 21.2538 - val_loss: 288.6563 - val_root_mean_squared_error: 16.9899
# Epoch 4/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 3893.5081 - root_mean_squared_error: 62.3980 - val_loss: 6.6627 - val_root_mean_squared_error: 2.5812
# Epoch 5/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 3202.9551 - root_mean_squared_error: 56.5947 - val_loss: 32.3953 - val_root_mean_squared_error: 5.6917
# Epoch 6/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 114.0207 - root_mean_squared_error: 10.6780 - val_loss: 8.6606 - val_root_mean_squared_error: 2.9429
# Epoch 7/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 669.9201 - root_mean_squared_error: 25.8828 - val_loss: 6.9480 - val_root_mean_squared_error: 2.6359
# Epoch 8/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 24.4785 - root_mean_squared_error: 4.9476 - val_loss: 8.9300 - val_root_mean_squared_error: 2.9883
# Epoch 9/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.5441 - root_mean_squared_error: 2.5581 - val_loss: 5.9322 - val_root_mean_squared_error: 2.4356
# Epoch 10/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0531 - root_mean_squared_error: 2.4603 - val_loss: 5.9361 - val_root_mean_squared_error: 2.4364
# Epoch 11/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0540 - root_mean_squared_error: 2.4605 - val_loss: 5.9321 - val_root_mean_squared_error: 2.4356
# Epoch 12/30
# 5427/5427 [==============================] - 8s 2ms/step - loss: 6.0551 - root_mean_squared_error: 2.4607 - val_loss: 5.9343 - val_root_mean_squared_error: 2.4360
# Epoch 13/30
# 5427/5427 [==============================] - 8s 2ms/step - loss: 6.0548 - root_mean_squared_error: 2.4606 - val_loss: 5.9326 - val_root_mean_squared_error: 2.4357
# Epoch 14/30
# 5427/5427 [==============================] - 8s 2ms/step - loss: 6.0544 - root_mean_squared_error: 2.4606 - val_loss: 5.9323 - val_root_mean_squared_error: 2.4356
# Epoch 15/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0545 - root_mean_squared_error: 2.4606 - val_loss: 5.9321 - val_root_mean_squared_error: 2.4356
# Epoch 16/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0548 - root_mean_squared_error: 2.4606 - val_loss: 5.9329 - val_root_mean_squared_error: 2.4358
# Epoch 17/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0536 - root_mean_squared_error: 2.4604 - val_loss: 5.9353 - val_root_mean_squared_error: 2.4362
# Epoch 18/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0547 - root_mean_squared_error: 2.4606 - val_loss: 5.9326 - val_root_mean_squared_error: 2.4357
# Epoch 19/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0543 - root_mean_squared_error: 2.4606 - val_loss: 5.9327 - val_root_mean_squared_error: 2.4357
# Epoch 20/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0546 - root_mean_squared_error: 2.4606 - val_loss: 5.9345 - val_root_mean_squared_error: 2.4361
# Epoch 21/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0548 - root_mean_squared_error: 2.4607 - val_loss: 5.9323 - val_root_mean_squared_error: 2.4356
# Epoch 22/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0545 - root_mean_squared_error: 2.4606 - val_loss: 5.9329 - val_root_mean_squared_error: 2.4358
# Epoch 23/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0544 - root_mean_squared_error: 2.4606 - val_loss: 5.9349 - val_root_mean_squared_error: 2.4362
# Epoch 24/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0544 - root_mean_squared_error: 2.4606 - val_loss: 5.9321 - val_root_mean_squared_error: 2.4356
# Epoch 25/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0546 - root_mean_squared_error: 2.4606 - val_loss: 5.9344 - val_root_mean_squared_error: 2.4361
# Epoch 26/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0546 - root_mean_squared_error: 2.4606 - val_loss: 5.9331 - val_root_mean_squared_error: 2.4358
# Epoch 27/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0542 - root_mean_squared_error: 2.4605 - val_loss: 5.9321 - val_root_mean_squared_error: 2.4356
# Epoch 28/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0545 - root_mean_squared_error: 2.4606 - val_loss: 5.9326 - val_root_mean_squared_error: 2.4357
# Epoch 29/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0544 - root_mean_squared_error: 2.4606 - val_loss: 5.9327 - val_root_mean_squared_error: 2.4357
# Epoch 30/30
# 5427/5427 [==============================] - 8s 1ms/step - loss: 6.0542 - root_mean_squared_error: 2.4605 - val_loss: 5.9324 - val_root_mean_squared_error: 2.4357
# -------------------------

# %%
num_model = 0
for model in macroModel.models:
    model.save('model{num}.h5'.format(num=num_model))
    num_model += 1

# %% [markdown]
# ## Test

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202737 entries, 0 to 202736
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            202737 non-null  object
#  1   geoCluster    202737 non-null  int64
#  2   SKU           202737 non-null  int64
#  3   date          202737 non-null  object
#  4   price_filled  202737 non-null  float64
#  5   sales         0 non-null       float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 9.3+ MB

# %%
testing = merging_df(df_geo, test, df_sku)
testing
# Out:
#            SKU     Category  brandId  lagerUnitQuantity  trademark  \
# 0           24  Pomegranate        0                1.0          0
# 1           24  Pomegranate        0                1.0          0
# 2           24  Pomegranate        0                1.0          0
# 3           24  Pomegranate        0                1.0          0
# 4           24  Pomegranate        0                1.0          0
# ...        ...          ...      ...                ...        ...
# 202732  838137      Avocado        0                1.0       9666
# 202733  838137      Avocado        0                1.0       9666
# 202734  838137      Avocado        0                1.0       9666
# 202735  838137      Avocado        0                1.0       9666
# 202736  838137      Avocado        0                1.0       9666
#
#         countryOfOrigin            Group  geoCluster  cityId          ID  \
# 0                     0  Tropical fruits         323       1  RR27958569
# 1                     0  Tropical fruits         323       1  RR27958570
# 2                     0  Tropical fruits         323       1  RR27958571
# 3                     0  Tropical fruits         323       1  RR27958572
# 4                     0  Tropical fruits         323       1  RR27958573
# ...                 ...              ...         ...     ...         ...
# 202732                0  Tropical fruits        3230       0  RR31319319
# 202733                0  Tropical fruits        3230       0  RR31319320
# 202734                0  Tropical fruits        3230       0  RR31319321
# 202735                0  Tropical fruits        3230       0  RR31319322
# 202736                0  Tropical fruits        3230       0  RR31319323
#
#               date  price_filled  sales
# 0       2021-07-06         79.49    NaN
# 1       2021-07-07         79.49    NaN
# 2       2021-07-08         79.49    NaN
# 3       2021-07-09         79.49    NaN
# 4       2021-07-10         79.49    NaN
# ...            ...           ...    ...
# 202732  2021-07-15         51.99    NaN
# 202733  2021-07-16         52.59    NaN
# 202734  2021-07-17         52.29    NaN
# 202735  2021-07-18         52.59    NaN
# 202736  2021-07-19         52.59    NaN
#
# [202737 rows x 13 columns]

# %%
testing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202737 entries, 0 to 202736
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   SKU                202737 non-null  int64
#  1   Category           202737 non-null  category
#  2   brandId            202737 non-null  Int64
#  3   lagerUnitQuantity  202737 non-null  Float64
#  4   trademark          202737 non-null  Int64
#  5   countryOfOrigin    202737 non-null  Int64
#  6   Group              202737 non-null  category
#  7   geoCluster         202737 non-null  int64
#  8   cityId             202737 non-null  int64
#  9   ID                 202737 non-null  object
#  10  date               202737 non-null  object
#  11  price_filled       202737 non-null  float64
#  12  sales              0 non-null       float64
# dtypes: Float64(1), Int64(3), category(2), float64(2), int64(3), object(2)
# memory usage: 19.7+ MB

# %%
testing.drop(['ID', 'sales'], axis=1, inplace=True)

# %%
testing.date = pd.to_datetime(testing.date) 
testing.date = testing.date .map(dt.datetime.toordinal)
testing['date'] = testing['date'].astype(np.int64)

# %%
testing['Category'] = testing['Category'].map(mapping_categories) 
testing['Group'] = testing['Group'].map(mapping_group)

# %%
testing['brandId'] = testing['brandId'].astype("int64")
testing['Group'] = testing['Group'].astype("int64")
testing['Category'] = testing['Category'].astype("int64")
testing['SKU'] = testing['SKU'].astype("int64")
testing['geoCluster'] = testing['geoCluster'].astype("int64")
testing["cityId"] = testing['cityId'].astype("int64")
testing["date"] = testing["date"].astype("int64")
testing["price_filled"] = testing["price_filled"].astype("float64")
testing['lagerUnitQuantity'] = testing['lagerUnitQuantity'].astype('float64')
testing['trademark'] = testing['trademark'].astype('int64')
testing['countryOfOrigin'] = testing['countryOfOrigin'].astype('int64')

# %%
'''numeric_features_test = tf.convert_to_tensor(testing)

normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(numeric_features_test)'''
# Out:
# 'numeric_features_test = tf.convert_to_tensor(testing)\n\nnormalizer = tf.keras.layers.Normalization(axis=-1)\nnormalizer.adapt(numeric_features_test)'

# %%
testing
# Out:
#            SKU  Category  brandId  lagerUnitQuantity  trademark  \
# 0           24        24        0                1.0          0
# 1           24        24        0                1.0          0
# 2           24        24        0                1.0          0
# 3           24        24        0                1.0          0
# 4           24        24        0                1.0          0
# ...        ...       ...      ...                ...        ...
# 202732  838137         0        0                1.0       9666
# 202733  838137         0        0                1.0       9666
# 202734  838137         0        0                1.0       9666
# 202735  838137         0        0                1.0       9666
# 202736  838137         0        0                1.0       9666
#
#         countryOfOrigin  Group  geoCluster  cityId    date  price_filled
# 0                     0      3         323       1  737977         79.49
# 1                     0      3         323       1  737978         79.49
# 2                     0      3         323       1  737979         79.49
# 3                     0      3         323       1  737980         79.49
# 4                     0      3         323       1  737981         79.49
# ...                 ...    ...         ...     ...     ...           ...
# 202732                0      3        3230       0  737986         51.99
# 202733                0      3        3230       0  737987         52.59
# 202734                0      3        3230       0  737988         52.29
# 202735                0      3        3230       0  737989         52.59
# 202736                0      3        3230       0  737990         52.59
#
# [202737 rows x 11 columns]

# %%
df_split = []
idxs = []
for i in range(len(testing.Group.unique())):
    spl = testing[testing.Group == i]
    df_split.append(spl)
    idxs.append(spl.index.values)

# %%
def vectorization(a):
    numeric_features_test = tf.convert_to_tensor(a)
    
    normalizer = tf.keras.layers.Normalization(axis=-1)
    normalizer.adapt(numeric_features_test)
    return numeric_features_test

# %%
predictions_group = []

num_model = 0
for group_data in range(5):
    group_data = df_split[num_model]
    print(df_split[num_model].shape)
    print(len(idxs[num_model]))
    X = vectorization(group_data)
    pred = macroModel.predict(X, num_model)
    print(len(pred))
    predictions_group.append(pred)
    num_model += 1
# Out:
# (53023, 11)
# 53023
# 53023
# (24824, 11)
# 24824
# 24824
# (38202, 11)
# 38202
# 38202
# (52107, 11)
# 52107
# 52107
# (34581, 11)
# 34581
# 34581

# %%
for array in predictions_group:
    print(array.shape)
# Out:
# (53023, 1)
# (24824, 1)
# (38202, 1)
# (52107, 1)
# (34581, 1)

# %%
idxs = np.concatenate(idxs)
tt = np.concatenate(predictions_group)

# %%
idxs.shape
# Out:
# (202737,)

# %%
tt = tt.reshape(idxs.shape)

# %%
tt.shape
# Out:
# (202737,)

# %%
predictions = pd.DataFrame({'idxs':idxs, 'sales':tt})

# %%
predictions.sort_values(by=['idxs'], inplace=True)
predictions.set_index('idxs', inplace=True)
predictions
# Out:
#            sales
# idxs
# 0       3.610947
# 1       3.610947
# 2       3.610947
# 3       3.610947
# 4       3.610947
# ...          ...
# 202732  3.610947
# 202733  3.610947
# 202734  3.610947
# 202735  3.610947
# 202736  3.610947
#
# [202737 rows x 1 columns]

# %%
test['sales'] = predictions['sales']
test
# Out:
#                 ID  geoCluster     SKU        date  price_filled     sales
# 0       RR27956447          21   32485  2021-07-08         39.69  3.610947
# 1       RR27956448          21   32485  2021-07-09         39.69  3.610947
# 2       RR27956449          21   32485  2021-07-10         39.69  3.610947
# 3       RR27956450          21   32485  2021-07-11         39.69  3.610947
# 4       RR27956451          21   32485  2021-07-12         39.69  3.610947
# ...            ...         ...     ...         ...           ...       ...
# 202732  RR55912539        3230  711838  2021-07-15         28.49  3.610947
# 202733  RR55912540        3230  711838  2021-07-16         28.49  3.610947
# 202734  RR55912541        3230  711838  2021-07-17         28.49  3.610947
# 202735  RR55912542        3230  711838  2021-07-18         28.49  3.610947
# 202736  RR55912543        3230  711838  2021-07-19         28.49  3.610947
#
# [202737 rows x 6 columns]

# %%
test.to_csv('predictions.csv')
