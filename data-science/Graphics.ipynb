# %%
import pandas as pd

df = pd.read_csv('Data - Hack UPC/data_show.csv')

df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#    Unnamed: 0  SKU     Category  brandId  lagerUnitQuantity  trademark  \
# 0           0   24  Pomegranate        0                1.0          0
# 1           1   24  Pomegranate        0                1.0          0
# 2           2   24  Pomegranate        0                1.0          0
# 3           3   24  Pomegranate        0                1.0          0
# 4           4   24  Pomegranate        0                1.0          0
#
#    countryOfOrigin            Group  geoCluster  cityId       date  price  \
# 0                0  Tropical fruits         323       1 2021-03-03  79.49
# 1                0  Tropical fruits        1934       0 2020-11-05  46.89
# 2                0  Tropical fruits        1934       0 2020-11-26  54.09
# 3                0  Tropical fruits        1934       0 2020-11-28  54.09
# 4                0  Tropical fruits        1934       0 2020-12-09  62.39
#
#    sales
# 0    0.4
# 1    1.4
# 2    2.5
# 3    1.4
# 4    3.0

# %%
import plotly.express as px

fig = px.line(df.groupby('date').sum()['price'])
fig.show()

# %% [markdown]
# El brand, id, trademarking, countryorigin, Si tenen un 0 els he categoritzat com a altres
# El category té 5 nan els hem reemplaçat pel grup

# %%
fig = px.bar(df.groupby('Category').size())
fig.show()

# %%
g = df.groupby('Group').size().to_frame()
g['Group'] = g.index
fig = px.bar(g, color='Group')
fig.show()
